# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
import yfinance as yf

# %%
# Daten herunterladen und DataFrame erstellen
df = yf.download('TSLA', start='2015-01-01', end='2020-07-01')

# Index zurücksetzen und "Date" als separate Spalte erstellen
df.reset_index(inplace=True)

# Spalte "Date" umbenennen
df.rename(columns={'index': 'Date'}, inplace=True)

# Überprüfen Sie das aktualisierte DataFrame
print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2015-01-02  14.858000  14.883333  14.217333  14.620667  14.620667  71466000
# 1 2015-01-05  14.303333  14.433333  13.810667  14.006000  14.006000  80527500
# 2 2015-01-06  14.004000  14.280000  13.614000  14.085333  14.085333  93928500
# 3 2015-01-07  14.223333  14.318667  13.985333  14.063333  14.063333  44526000
# 4 2015-01-08  14.187333  14.253333  14.000667  14.041333  14.041333  51637500

# %%
print("Number of rows and columns:", df.shape)
df.head(5)
# Out:
# Number of rows and columns: (1383, 7)
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2015-01-02  14.858000  14.883333  14.217333  14.620667  14.620667  71466000
# 1 2015-01-05  14.303333  14.433333  13.810667  14.006000  14.006000  80527500
# 2 2015-01-06  14.004000  14.280000  13.614000  14.085333  14.085333  93928500
# 3 2015-01-07  14.223333  14.318667  13.985333  14.063333  14.063333  44526000
# 4 2015-01-08  14.187333  14.253333  14.000667  14.041333  14.041333  51637500

# %%
training_set = df.iloc[:800, 1:2].values
test_set = df.iloc[800:, 1:2].values

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
#(740, 60, 1)
# Out:
#   Cell In[6], line 9
#     X_train, y_train = np.array(X_train), np.array(y_train)X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
#                                                            ^
# SyntaxError: invalid syntax

# %%
sc = MinMaxScaler(feature_range=(0, 1))

training_set_scaled = sc.fit_transform(training_set)

X_train = []
y_train = []

for i in range(60, 800):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
model = Sequential()#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 13s 81ms/step - loss: 0.0488
# Epoch 2/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0127
# Epoch 3/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0111
# Epoch 4/100
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0102
# Epoch 5/100
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0106
# Epoch 6/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0098
# Epoch 7/100
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0093
# Epoch 8/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0090
# Epoch 9/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0090
# Epoch 10/100
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0087
# Epoch 11/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0081
# Epoch 12/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0070
# Epoch 13/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0069
# Epoch 14/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0077
# Epoch 15/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0072
# Epoch 16/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0076
# Epoch 17/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0066
# Epoch 18/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0058
# Epoch 19/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0075
# Epoch 20/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0055
# Epoch 21/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0056
# Epoch 22/100
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0051
# Epoch 23/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0056
# Epoch 24/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0055
# Epoch 25/100
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0052
# Epoch 26/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0052
# Epoch 27/100
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0051
# Epoch 28/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0059
# Epoch 29/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0053
# Epoch 30/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0059
# Epoch 31/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0051
# Epoch 32/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0043
# Epoch 33/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0048
# Epoch 34/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0047
# Epoch 35/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0044
# Epoch 36/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0043
# Epoch 37/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0043
# Epoch 38/100
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0056
# Epoch 39/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0044
# Epoch 40/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0043
# Epoch 41/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0048
# Epoch 42/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0043
# Epoch 43/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0045
# Epoch 44/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0040
# Epoch 45/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0039
# Epoch 46/100
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0037
# Epoch 47/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0043
# Epoch 48/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0038
# Epoch 49/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0036
# Epoch 50/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0037
# Epoch 51/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0042
# Epoch 52/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0039
# Epoch 53/100
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0038
# Epoch 54/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0036
# Epoch 55/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0036
# Epoch 56/100
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0038
# Epoch 57/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0034
# Epoch 58/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0031
# Epoch 59/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0032
# Epoch 60/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0039
# Epoch 61/100
# 24/24 [==============================] - 2s 92ms/step - loss: 0.0035
# Epoch 62/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0037
# Epoch 63/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0034
# Epoch 64/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0036
# Epoch 65/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0034
# Epoch 66/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0030
# Epoch 67/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0034
# Epoch 68/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0033
# Epoch 69/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0028
# Epoch 70/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0034
# Epoch 71/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0031
# Epoch 72/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0029
# Epoch 73/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0032
# Epoch 74/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0030
# Epoch 75/100
# 24/24 [==============================] - 2s 85ms/step - loss: 0.0033
# Epoch 76/100
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0028
# Epoch 77/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0031
# Epoch 78/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0026
# Epoch 79/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0024
# Epoch 80/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0026
# Epoch 81/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0027
# Epoch 82/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0027
# Epoch 83/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0029
# Epoch 84/100
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0032
# Epoch 85/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0026
# Epoch 86/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0032
# Epoch 87/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0028
# Epoch 88/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0024
# Epoch 89/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0024
# Epoch 90/100
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0026
# Epoch 91/100
# 24/24 [==============================] - 2s 92ms/step - loss: 0.0024
# Epoch 92/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0026
# Epoch 93/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0026
# Epoch 94/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0025
# Epoch 95/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0024
# Epoch 96/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0025
# Epoch 97/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0024
# Epoch 98/100
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0025
# Epoch 99/100
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0022
# Epoch 100/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0024

# %%
dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[800:, 1:2]

dataset_total = pd.concat((dataset_train, dataset_test), axis=0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1, 1)

inputs = sc.transform(inputs)

X_test = []

for i in range(60, 519):
    X_test.append(inputs[i-60:i, 0])

X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

print(X_test.shape)
# Out:
# (459, 60, 1)

# %%
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 15/15 [==============================] - 4s 32ms/step

# %%
# Visualising the results
plt.plot(df.loc[800:, "Date"],dataset_test.values, color = "red", label = "Real TESLA Stock Price")
plt.plot(df.loc[800:, "Date"],predicted_stock_price, color = "blue", label = "Predicted TESLA Stock Price")
plt.xticks(np.arange(0,459,50))
plt.title("TESLA Stock Price Prediction")
plt.xlabel("Time")
plt.ylabel("TESLA Stock Price")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 3
#       1 # Visualising the results
#       2 plt.plot(df.loc[800:, "Date"],dataset_test.values, color = "red", label = "Real TESLA Stock Price")
# ----> 3 plt.plot(df.loc[800:, "Date"],predicted_stock_price, color = "blue", label = "Predicted TESLA Stock Price")
#       4 plt.xticks(np.arange(0,459,50))
#       5 plt.title("TESLA Stock Price Prediction")
#
# File ~\.conda\envs\tf_new\lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\.conda\envs\tf_new\lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~\.conda\envs\tf_new\lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\.conda\envs\tf_new\lib\site-packages\matplotlib\axes\_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (583,) and (459, 1)
